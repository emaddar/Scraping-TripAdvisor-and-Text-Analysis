# %% [markdown]
# ## Import the Libraries

# %%
# Import the libraries.
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Extract the HTML and create a BeautifulSoup object.
url = ('https://www.tripadvisor.fr/Hotels-g187178-Lille_Nord_Hauts_de_France-Hotels.html')

user_agent = ({'User-Agent':
			'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
			AppleWebKit/537.36 (KHTML, like Gecko) \
			Chrome/90.0.4430.212 Safari/537.36',
			'Accept-Language': 'en-US, en;q=0.5'})

def get_page_contents(url):
    page = requests.get(url, headers = user_agent)
    return BeautifulSoup(page.text, 'html.parser')

soup = get_page_contents(url)

# Find and extract the data elements.
hotels = []
for name in soup.findAll('div',{'class':'listing_title'}):
    hotels.append(name.text.strip())

ratings = []
for rating in soup.findAll('a',{'class':'ui_bubble_rating'}):
    ratings.append(rating['alt'])  

reviews = []
for review in soup.findAll('a',{'class':'review_count'}):
    reviews.append(review.text.strip())

prices = []
for p in soup.findAll('div',{'class':'price-wrap'}):
    prices.append(p.text.replace('₹','').strip())  

links = []
adress = []
i = 1
for l in soup.find_all('a', {'class': 'property_title prominent'}):
    url_page = f"https://www.tripadvisor.fr/{l['href']}"
    links.append(url_page)

    new_soup = get_page_contents(url_page)    
    adress.append(new_soup.find('span',{'class':'fHvkI PTrfg'}).text)
    print(f"Adress hotel : {i} : OK")
    i += 1

# Create the dictionary.
dict = {'Hotel Names':hotels,'Ratings':ratings,'Number of Reviews':reviews,'Prices':prices, "Adress" : adress , "links": links}

# Create the dataframe.
hotel_list = pd.DataFrame.from_dict(dict)
hotel_list.head(10)
# Out:
# Adress : 1 : OK
# Adress : 2 : OK
# Adress : 3 : OK
# Adress : 4 : OK
# Adress : 5 : OK
# Adress : 6 : OK
# Adress : 7 : OK
# Adress : 8 : OK
# Adress : 9 : OK
# Adress : 10 : OK
# Adress : 11 : OK
# Adress : 12 : OK
# Adress : 13 : OK
# Adress : 14 : OK
# Adress : 15 : OK
# Adress : 16 : OK
# Adress : 17 : OK
# Adress : 18 : OK
# Adress : 19 : OK
# Adress : 20 : OK
# Adress : 21 : OK
# Adress : 22 : OK
# Adress : 23 : OK
# Adress : 24 : OK
# Adress : 25 : OK
# Adress : 26 : OK
# Adress : 27 : OK
# Adress : 28 : OK
# Adress : 29 : OK
# Adress : 30 : OK
# Adress : 31 : OK
# Adress : 32 : OK
# Adress : 33 : OK
# Adress : 34 : OK
#                                         Hotel Names           Ratings  \
# 0                  Annonce      Hôtel Saint Maurice    4 sur 5 bulles
# 1  1. Hotel L'Arbre Voyageur, BW Premier Collection    5 sur 5 bulles
# 2                            2. Hôtel Saint Maurice    4 sur 5 bulles
# 3                                  3. Carlton Hotel    4 sur 5 bulles
# 4                             4. Mama Shelter Lille  4,5 sur 5 bulles
# 5                           5. Grand Hôtel Bellevue  4,5 sur 5 bulles
# 6  Annonce      B&B HOTEL Lille Lillénium Eurasanté  4,5 sur 5 bulles
# 7              6. Boa Hotel BW Signature Collection    5 sur 5 bulles
# 8                                7. Moxy Lille City  4,5 sur 5 bulles
